# %% [markdown]
# ## Step 1: Imports & Setup

# %%
# --------------------------
# Step 1: Import All Libraries (Consolidated)
# --------------------------
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from torchvision.models import (
    resnet18, resnet50, convnext_tiny, vit_b_16, vit_l_16, swin_t, swin_b,
    ResNet18_Weights, ResNet50_Weights, ConvNeXt_Tiny_Weights,
    ViT_B_16_Weights, ViT_L_16_Weights, Swin_T_Weights, Swin_B_Weights
)
from torchinfo import summary
from tqdm.auto import tqdm

# Device configuration (single definition)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Step 2: Define your dataset class

# %%
# Step 2: AQIDataset (Unchanged, but kept for completeness)
# --------------------------
class AQIDataset(Dataset):
    def __init__(self, images_dir, labels_csv, transform=None):
        self.images_dir = images_dir
        self.labels = pd.read_csv(labels_csv)
        self.transform = transform

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        row = self.labels.iloc[idx]
        img_name = row['Filename']
        img_path = os.path.join(self.images_dir, img_name)
        image = Image.open(img_path).convert('RGB')

        # Retrieve 7 pollutant labels (match training: 'PM25' not 'PM2.5')
        labels = row[['CO']].values.astype('float32')
        labels = torch.tensor(labels)

        if self.transform:
            image = self.transform(image)

        return image, labels

# %% [markdown]
# ## Step 3: Prepare datasets and dataloaders

# %%
# Data Transforms
data_transforms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])

# Read labels.csv
labels_df = pd.read_csv('all_timeslot_cleaned.csv')

# Split into train and validation sets
train_df, val_df = train_test_split(labels_df, test_size=0.1, random_state=42, shuffle=True)

# Save temporary csv for convenience
train_df.to_csv('train_labels_CO.csv', index=False)
val_df.to_csv('val_labels_CO.csv', index=False)

# Prepare Dataset objects
train_dataset = AQIDataset('all_images/', 'train_labels_CO.csv', transform=data_transforms)
print(f'Len of training: {len(train_dataset)}')
val_dataset = AQIDataset('all_images/', 'val_labels_CO.csv', transform=data_transforms)
print(f'Len of validation: {len(val_dataset)}')
# Data Loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
# Out:
# Len of training: 18550
# Len of validation: 2062

# %% [markdown]
# ## Step 4: Define your Model

# %%
# Step 3: Backbone & AQINet (Match Training Exactly)
# --------------------------
_BACKBONES = {
    "resnet18":  ("resnet", resnet18, ResNet18_Weights),
    "resnet50":  ("resnet", resnet50, ResNet50_Weights),
    "convnext_tiny": ("convnext", convnext_tiny, ConvNeXt_Tiny_Weights),
    "vit_b_16":  ("vit",  vit_b_16, ViT_B_16_Weights),
    "vit_l_16":  ("vit",  vit_l_16, ViT_L_16_Weights),
    "swin_t":    ("swin", swin_t, Swin_T_Weights),
    "swin_b":    ("swin", swin_b, Swin_B_Weights),
}

def _make_encoder(name: str, pretrained: bool = True):
    """Build encoder (exact copy from training)"""
    if name not in _BACKBONES:
        raise ValueError(f"Unknown backbone '{name}'. Choose from: {list(_BACKBONES.keys())}")

    family, ctor, weights_enum = _BACKBONES[name]
    weights = weights_enum.DEFAULT if pretrained else None
    m = ctor(weights=weights)

    if family == "resnet":
        feat_dim = m.fc.in_features
        m.fc = nn.Identity()
        encoder = m
    elif family == "convnext":
        # Critical: ConvNeXt encoder returns (N, 768, H, W) (no GAP here—GAP is in AQINet's encoder!)
        # This fixes the feature map dimension mismatch for CAM
        feat_dim = 768
        encoder = m.features  # ONLY the feature extractor (no AdaptiveAvgPool2d/Flatten)
    elif family == "vit":
        feat_dim = m.heads.head.in_features
        m.heads = nn.Identity()
        encoder = m
    elif family == "swin":
        feat_dim = m.head.in_features
        m.head = nn.Identity()
        encoder = m
    else:
        raise RuntimeError("Unhandled backbone family.")

    return encoder, feat_dim

class AQINet(nn.Module):
    """AQINet (exact copy from training)"""
    def __init__(self,
                 output_dim: int = 1,
                 backbone: str = "vit_b_16",
                 pretrained: bool = True,
                 head_hidden: int = 256,
                 dropout: float = 0.2):
        super().__init__()
        self.backbone_name = backbone
        self.encoder, feat_dim = _make_encoder(backbone, pretrained)

        # For ConvNeXt: Add GAP to match other backbones' (N, feat_dim) output
        if backbone == "convnext_tiny":
            self.encoder = nn.Sequential(
                self.encoder,  # ConvNeXt features (N, 768, 7, 7)
                nn.AdaptiveAvgPool2d(1),  # (N, 768, 1, 1)
                nn.Flatten(1)  # (N, 768)
            )

        self.head = nn.Sequential(
            nn.LayerNorm(feat_dim),
            nn.Linear(feat_dim, head_hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(head_hidden, output_dim)
        )

    def forward(self, img):
        feats = self.encoder(img)
        if feats.dim() == 4:
            feats = feats.squeeze(-1).squeeze(-1)
        return self.head(feats)

# %%
# Examples
# -----------------------------
# ViT base 16x16
# model = AQINet(backbone="vit_b_16").to(device)

# Swin-T
# model = AQINet(backbone="swin_t").to(device)

# ResNet-50
model = AQINet(backbone="resnet18").to(device)

# ConvNeXt-Tiny
# model = AQINet(backbone="convnext_tiny").to(device)
#

# %%
from torchinfo import summary
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total     = sum(p.numel() for p in model.parameters())
print(f"Trainable params: {trainable}/{total}")
summary(model.to(device))
# Out:
# Device: cuda
# Trainable params: 11309121/11309121
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# AQINet                                        --
# ├─ResNet: 1-1                                 --
# │    └─Conv2d: 2-1                            9,408
# │    └─BatchNorm2d: 2-2                       128
# │    └─ReLU: 2-3                              --
# │    └─MaxPool2d: 2-4                         --
# │    └─Sequential: 2-5                        --
# │    │    └─BasicBlock: 3-1                   73,984
# │    │    └─BasicBlock: 3-2                   73,984
# │    └─Sequential: 2-6                        --
# │    │    └─BasicBlock: 3-3                   230,144
# │    │    └─BasicBlock: 3-4                   295,424
# │    └─Sequential: 2-7                        --
# │    │    └─BasicBlock: 3-5                   919,040
# │    │    └─BasicBlock: 3-6                   1,180,672
# │    └─Sequential: 2-8                        --
# │    │    └─BasicBlock: 3-7                   3,673,088
# │    │    └─BasicBlock: 3-8                   4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 --
# │    └─Identity: 2-10                         --
# ├─Sequential: 1-2                             --
# │    └─LayerNorm: 2-11                        1,024
# │    └─Linear: 2-12                           131,328
# │    └─GELU: 2-13                             --
# │    └─Dropout: 2-14                          --
# │    └─Linear: 2-15                           257
# ======================================================================
# Total params: 11,309,121
# Trainable params: 11,309,121
# Non-trainable params: 0
# ======================================================================

# %% [markdown]
# ## Step 5: Define Loss and Optimizer

# %%
criterion = nn.MSELoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4)

# %% [markdown]
# ## Step 6: Training Loop

# %%
import numpy as np
import torch
from tqdm.auto import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

num_epochs = 50
best_model_path = "best_single_image_model_CO.pth"
columns = ['CO']
num_pollutants = len(columns)

# History dictionary to track metrics
history = {
    'train_loss': [],
    'val_loss': [],
    'train_r2': [],
    'val_r2': [],
    'mae': [],
    'rmse': [],
    'per_pollutant_r2': [[] for _ in range(num_pollutants)]
}

best_val_r2 = -np.inf

for epoch in tqdm(range(num_epochs), desc="Training Progress"):
    # ------------------------ Training ------------------------
    model.train()
    train_loss = 0.0
    y_train_true, y_train_pred = [], []

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * images.size(0)
        # Collect predictions for R² calculation
        y_train_true.extend(labels.detach().cpu().numpy())
        y_train_pred.extend(outputs.detach().cpu().numpy())

    train_loss /= len(train_loader.dataset)
    history['train_loss'].append(train_loss)

    # Compute training R²
    y_train_true = np.array(y_train_true)
    y_train_pred = np.array(y_train_pred)
    train_r2 = r2_score(y_train_true, y_train_pred)
    history['train_r2'].append(train_r2)

    # ------------------------ Validation ------------------------
    model.eval()
    val_loss = 0.0
    y_val_true, y_val_pred = [], []

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            val_loss += loss.item() * images.size(0)
            y_val_true.extend(labels.cpu().numpy())
            y_val_pred.extend(outputs.cpu().numpy())

    val_loss /= len(val_loader.dataset)
    history['val_loss'].append(val_loss)

    # Compute validation metrics
    y_val_true = np.array(y_val_true)
    y_val_pred = np.array(y_val_pred)
    mae = mean_absolute_error(y_val_true, y_val_pred)
    rmse = np.sqrt(mean_squared_error(y_val_true, y_val_pred))
    val_r2 = r2_score(y_val_true, y_val_pred)
    
    history['mae'].append(mae)
    history['rmse'].append(rmse)
    history['val_r2'].append(val_r2)

    # Print epoch summary
    print(f"\nEpoch [{epoch+1}/{num_epochs}]")
    print(f"Train Loss: {train_loss:.4f} | Train R²: {train_r2:.4f}")
    print(f"Val Loss: {val_loss:.4f} | Val R²: {val_r2:.4f}")
    print(f"MAE: {mae:.4f} | RMSE: {rmse:.4f}")

    # Per-pollutant R² scores
    print("Per-pollutant Validation R² Scores:")
    for i, name in enumerate(columns):
        pollutant_r2 = r2_score(y_val_true[:, i], y_val_pred[:, i])
        history['per_pollutant_r2'][i].append(pollutant_r2)
        print(f"  {name}: {pollutant_r2:.4f}")

    # Save best model
    if val_r2 > best_val_r2:
        best_val_r2 = val_r2
        torch.save(model.state_dict(), best_model_path)
        print(f"✅ Saved best model (Val R²: {best_val_r2:.4f})")

print('\n***Training Complete***')
print(f"Best Validation R²: {best_val_r2:.4f}")
# Out:
# Training Progress:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch [1/50]
# Train Loss: 0.1009 | Train R²: 0.7393
# Val Loss: 0.0380 | Val R²: 0.9038
# MAE: 0.1349 | RMSE: 0.1950
# Per-pollutant Validation R² Scores:
#   CO: 0.9038
# ✅ Saved best model (Val R²: 0.9038)
#
# Epoch [2/50]
# Train Loss: 0.0310 | Train R²: 0.9199
# Val Loss: 0.0259 | Val R²: 0.9344
# MAE: 0.1070 | RMSE: 0.1610
# Per-pollutant Validation R² Scores:
#   CO: 0.9344
# ✅ Saved best model (Val R²: 0.9344)
#
# Epoch [3/50]
# Train Loss: 0.0217 | Train R²: 0.9440
# Val Loss: 0.0247 | Val R²: 0.9375
# MAE: 0.0982 | RMSE: 0.1571
# Per-pollutant Validation R² Scores:
#   CO: 0.9375
# ✅ Saved best model (Val R²: 0.9375)
#
# Epoch [4/50]
# Train Loss: 0.0158 | Train R²: 0.9593
# Val Loss: 0.0243 | Val R²: 0.9384
# MAE: 0.0994 | RMSE: 0.1560
# Per-pollutant Validation R² Scores:
#   CO: 0.9384
# ✅ Saved best model (Val R²: 0.9384)
#
# Epoch [5/50]
# Train Loss: 0.0138 | Train R²: 0.9644
# Val Loss: 0.0223 | Val R²: 0.9436
# MAE: 0.0980 | RMSE: 0.1493
# Per-pollutant Validation R² Scores:
#   CO: 0.9436
# ✅ Saved best model (Val R²: 0.9436)
#
# Epoch [6/50]
# Train Loss: 0.0121 | Train R²: 0.9687
# Val Loss: 0.0216 | Val R²: 0.9454
# MAE: 0.0926 | RMSE: 0.1469
# Per-pollutant Validation R² Scores:
#   CO: 0.9454
# ✅ Saved best model (Val R²: 0.9454)
#
# Epoch [7/50]
# Train Loss: 0.0107 | Train R²: 0.9724
# Val Loss: 0.0213 | Val R²: 0.9461
# MAE: 0.0879 | RMSE: 0.1460
# Per-pollutant Validation R² Scores:
#   CO: 0.9461
# ✅ Saved best model (Val R²: 0.9461)
#
# Epoch [8/50]
# Train Loss: 0.0099 | Train R²: 0.9744
# Val Loss: 0.0197 | Val R²: 0.9502
# MAE: 0.0879 | RMSE: 0.1402
# Per-pollutant Validation R² Scores:
#   CO: 0.9502
# ✅ Saved best model (Val R²: 0.9502)
#
# Epoch [9/50]
# Train Loss: 0.0097 | Train R²: 0.9750
# Val Loss: 0.0198 | Val R²: 0.9500
# MAE: 0.0908 | RMSE: 0.1406
# Per-pollutant Validation R² Scores:
#   CO: 0.9500
#
# Epoch [10/50]
# Train Loss: 0.0090 | Train R²: 0.9768
# Val Loss: 0.0192 | Val R²: 0.9515
# MAE: 0.0874 | RMSE: 0.1384
# Per-pollutant Validation R² Scores:
#   CO: 0.9515
# ✅ Saved best model (Val R²: 0.9515)
#
# Epoch [11/50]
# Train Loss: 0.0084 | Train R²: 0.9784
# Val Loss: 0.0201 | Val R²: 0.9491
# MAE: 0.0876 | RMSE: 0.1419
# Per-pollutant Validation R² Scores:
#   CO: 0.9491
#
# Epoch [12/50]
# Train Loss: 0.0078 | Train R²: 0.9799
# Val Loss: 0.0184 | Val R²: 0.9533
# MAE: 0.0832 | RMSE: 0.1358
# Per-pollutant Validation R² Scores:
#   CO: 0.9533
# ✅ Saved best model (Val R²: 0.9533)
#
# Epoch [13/50]
# Train Loss: 0.0077 | Train R²: 0.9802
# Val Loss: 0.0194 | Val R²: 0.9508
# MAE: 0.0873 | RMSE: 0.1394
# Per-pollutant Validation R² Scores:
#   CO: 0.9508
#
# Epoch [14/50]
# Train Loss: 0.0077 | Train R²: 0.9802
# Val Loss: 0.0175 | Val R²: 0.9557
# MAE: 0.0816 | RMSE: 0.1324
# Per-pollutant Validation R² Scores:
#   CO: 0.9557
# ✅ Saved best model (Val R²: 0.9557)
#
# Epoch [15/50]
# Train Loss: 0.0076 | Train R²: 0.9804
# Val Loss: 0.0186 | Val R²: 0.9531
# MAE: 0.0804 | RMSE: 0.1362
# Per-pollutant Validation R² Scores:
#   CO: 0.9531
#
# Epoch [16/50]
# Train Loss: 0.0072 | Train R²: 0.9814
# Val Loss: 0.0176 | Val R²: 0.9554
# MAE: 0.0790 | RMSE: 0.1328
# Per-pollutant Validation R² Scores:
#   CO: 0.9554
#
# Epoch [17/50]
# Train Loss: 0.0069 | Train R²: 0.9822
# Val Loss: 0.0170 | Val R²: 0.9571
# MAE: 0.0808 | RMSE: 0.1302
# Per-pollutant Validation R² Scores:
#   CO: 0.9571
# ✅ Saved best model (Val R²: 0.9571)
#
# Epoch [18/50]
# Train Loss: 0.0066 | Train R²: 0.9829
# Val Loss: 0.0188 | Val R²: 0.9524
# MAE: 0.0822 | RMSE: 0.1372
# Per-pollutant Validation R² Scores:
#   CO: 0.9524
#
# Epoch [19/50]
# Train Loss: 0.0064 | Train R²: 0.9834
# Val Loss: 0.0180 | Val R²: 0.9545
# MAE: 0.0798 | RMSE: 0.1341
# Per-pollutant Validation R² Scores:
#   CO: 0.9545
#
# Epoch [20/50]
# Train Loss: 0.0061 | Train R²: 0.9843
# Val Loss: 0.0165 | Val R²: 0.9582
# MAE: 0.0736 | RMSE: 0.1285
# Per-pollutant Validation R² Scores:
#   CO: 0.9582
# ✅ Saved best model (Val R²: 0.9582)
#
# Epoch [21/50]
# Train Loss: 0.0061 | Train R²: 0.9842
# Val Loss: 0.0176 | Val R²: 0.9554
# MAE: 0.0759 | RMSE: 0.1327
# Per-pollutant Validation R² Scores:
#   CO: 0.9554
#
# Epoch [22/50]
# Train Loss: 0.0056 | Train R²: 0.9855
# Val Loss: 0.0177 | Val R²: 0.9551
# MAE: 0.0763 | RMSE: 0.1332
# Per-pollutant Validation R² Scores:
#   CO: 0.9551
#
# Epoch [23/50]
# Train Loss: 0.0057 | Train R²: 0.9852
# Val Loss: 0.0179 | Val R²: 0.9548
# MAE: 0.0788 | RMSE: 0.1337
# Per-pollutant Validation R² Scores:
#   CO: 0.9548
#
# Epoch [24/50]
# Train Loss: 0.0058 | Train R²: 0.9850
# Val Loss: 0.0182 | Val R²: 0.9540
# MAE: 0.0787 | RMSE: 0.1348
# Per-pollutant Validation R² Scores:
#   CO: 0.9540
#
# Epoch [25/50]
# Train Loss: 0.0056 | Train R²: 0.9856
# Val Loss: 0.0168 | Val R²: 0.9574
# MAE: 0.0756 | RMSE: 0.1298
# Per-pollutant Validation R² Scores:
#   CO: 0.9574
#
# Epoch [26/50]
# Train Loss: 0.0058 | Train R²: 0.9850
# Val Loss: 0.0174 | Val R²: 0.9560
# MAE: 0.0764 | RMSE: 0.1319
# Per-pollutant Validation R² Scores:
#   CO: 0.9560
#
# Epoch [27/50]
# Train Loss: 0.0056 | Train R²: 0.9856
# Val Loss: 0.0176 | Val R²: 0.9554
# MAE: 0.0753 | RMSE: 0.1328
# Per-pollutant Validation R² Scores:
#   CO: 0.9554
#
# Epoch [28/50]
# Train Loss: 0.0052 | Train R²: 0.9865
# Val Loss: 0.0163 | Val R²: 0.9587
# MAE: 0.0724 | RMSE: 0.1278
# Per-pollutant Validation R² Scores:
#   CO: 0.9587
# ✅ Saved best model (Val R²: 0.9587)
#
# Epoch [29/50]
# Train Loss: 0.0051 | Train R²: 0.9868
# Val Loss: 0.0172 | Val R²: 0.9564
# MAE: 0.0738 | RMSE: 0.1312
# Per-pollutant Validation R² Scores:
#   CO: 0.9564
#
# Epoch [30/50]
# Train Loss: 0.0050 | Train R²: 0.9871
# Val Loss: 0.0158 | Val R²: 0.9599
# MAE: 0.0752 | RMSE: 0.1258
# Per-pollutant Validation R² Scores:
#   CO: 0.9599
# ✅ Saved best model (Val R²: 0.9599)
#
# Epoch [31/50]
# Train Loss: 0.0048 | Train R²: 0.9875
# Val Loss: 0.0167 | Val R²: 0.9577
# MAE: 0.0740 | RMSE: 0.1293
# Per-pollutant Validation R² Scores:
#   CO: 0.9577
#
# Epoch [32/50]
# Train Loss: 0.0048 | Train R²: 0.9876
# Val Loss: 0.0166 | Val R²: 0.9580
# MAE: 0.0722 | RMSE: 0.1289
# Per-pollutant Validation R² Scores:
#   CO: 0.9580
#
# Epoch [33/50]
# Train Loss: 0.0046 | Train R²: 0.9880
# Val Loss: 0.0169 | Val R²: 0.9572
# MAE: 0.0720 | RMSE: 0.1300
# Per-pollutant Validation R² Scores:
#   CO: 0.9572
#
# Epoch [34/50]
# Train Loss: 0.0048 | Train R²: 0.9875
# Val Loss: 0.0179 | Val R²: 0.9548
# MAE: 0.0742 | RMSE: 0.1337
# Per-pollutant Validation R² Scores:
#   CO: 0.9548
#
# Epoch [35/50]
# Train Loss: 0.0046 | Train R²: 0.9881
# Val Loss: 0.0170 | Val R²: 0.9569
# MAE: 0.0749 | RMSE: 0.1306
# Per-pollutant Validation R² Scores:
#   CO: 0.9569
#
# Epoch [36/50]
# Train Loss: 0.0044 | Train R²: 0.9886
# Val Loss: 0.0166 | Val R²: 0.9581
# MAE: 0.0696 | RMSE: 0.1287
# Per-pollutant Validation R² Scores:
#   CO: 0.9581
#
# Epoch [37/50]
# Train Loss: 0.0044 | Train R²: 0.9888
# Val Loss: 0.0168 | Val R²: 0.9574
# MAE: 0.0705 | RMSE: 0.1297
# Per-pollutant Validation R² Scores:
#   CO: 0.9574
#
# Epoch [38/50]
# Train Loss: 0.0044 | Train R²: 0.9887
# Val Loss: 0.0163 | Val R²: 0.9587
# MAE: 0.0723 | RMSE: 0.1277
# Per-pollutant Validation R² Scores:
#   CO: 0.9587
#
# Epoch [39/50]
# Train Loss: 0.0044 | Train R²: 0.9885
# Val Loss: 0.0159 | Val R²: 0.9599
# MAE: 0.0692 | RMSE: 0.1259
# Per-pollutant Validation R² Scores:
#   CO: 0.9599
#
# Epoch [40/50]
# Train Loss: 0.0043 | Train R²: 0.9889
# Val Loss: 0.0155 | Val R²: 0.9608
# MAE: 0.0691 | RMSE: 0.1245
# Per-pollutant Validation R² Scores:
#   CO: 0.9608
# ✅ Saved best model (Val R²: 0.9608)
#
# Epoch [41/50]
# Train Loss: 0.0041 | Train R²: 0.9894
# Val Loss: 0.0159 | Val R²: 0.9598
# MAE: 0.0700 | RMSE: 0.1261
# Per-pollutant Validation R² Scores:
#   CO: 0.9598
#
# Epoch [42/50]
# Train Loss: 0.0041 | Train R²: 0.9894
# Val Loss: 0.0157 | Val R²: 0.9602
# MAE: 0.0678 | RMSE: 0.1255
# Per-pollutant Validation R² Scores:
#   CO: 0.9602
#
# Epoch [43/50]
# Train Loss: 0.0040 | Train R²: 0.9896
# Val Loss: 0.0173 | Val R²: 0.9563
# MAE: 0.0767 | RMSE: 0.1315
# Per-pollutant Validation R² Scores:
#   CO: 0.9563
#
# Epoch [44/50]
# Train Loss: 0.0040 | Train R²: 0.9896
# Val Loss: 0.0161 | Val R²: 0.9593
# MAE: 0.0708 | RMSE: 0.1269
# Per-pollutant Validation R² Scores:
#   CO: 0.9593
#
# Epoch [45/50]
# Train Loss: 0.0038 | Train R²: 0.9901
# Val Loss: 0.0157 | Val R²: 0.9602
# MAE: 0.0704 | RMSE: 0.1254
# Per-pollutant Validation R² Scores:
#   CO: 0.9602
#
# Epoch [46/50]
# Train Loss: 0.0039 | Train R²: 0.9900
# Val Loss: 0.0156 | Val R²: 0.9605
# MAE: 0.0692 | RMSE: 0.1250
# Per-pollutant Validation R² Scores:
#   CO: 0.9605
#
# Epoch [47/50]
# Train Loss: 0.0040 | Train R²: 0.9897
# Val Loss: 0.0165 | Val R²: 0.9583
# MAE: 0.0683 | RMSE: 0.1283
# Per-pollutant Validation R² Scores:
#   CO: 0.9583
#
# Epoch [48/50]
# Train Loss: 0.0038 | Train R²: 0.9903
# Val Loss: 0.0158 | Val R²: 0.9601
# MAE: 0.0682 | RMSE: 0.1256
# Per-pollutant Validation R² Scores:
#   CO: 0.9601
#
# Epoch [49/50]
# Train Loss: 0.0037 | Train R²: 0.9903
# Val Loss: 0.0150 | Val R²: 0.9620
# MAE: 0.0669 | RMSE: 0.1226
# Per-pollutant Validation R² Scores:
#   CO: 0.9620
# ✅ Saved best model (Val R²: 0.9620)
#
# Epoch [50/50]
# Train Loss: 0.0037 | Train R²: 0.9905
# Val Loss: 0.0160 | Val R²: 0.9596
# MAE: 0.0686 | RMSE: 0.1263
# Per-pollutant Validation R² Scores:
#   CO: 0.9596
#
# ***Training Complete***
# Best Validation R²: 0.9620

# %%
# ========= Grad-CAM helper (ResNet18/50 + ConvNeXt-Tiny) =========
import torch
import torch.nn as nn
import torch.nn.functional as F
from typing import Tuple

def get_cam_target_layer(aqinet_model: nn.Module, backbone_name: str) -> nn.Module:
    """
    Returns the feature module to hook BEFORE any GAP/Flatten in AQINet.encoder.
    Supports: 'resnet18', 'resnet50', 'convnext_tiny'
    """
    name = backbone_name.lower()
    enc = aqinet_model.encoder

    if name in ("resnet18", "resnet50"):
        # encoder is the whole resnet with fc=Identity
        # last conv block is layer4[-1]
        return enc.layer4[-1]
    elif name == "convnext_tiny":
        # encoder is Sequential(features, GAP, Flatten)
        # find the ConvNeXt feature extractor robustly
        for m in enc.children():
            # ConvNeXt features module has attribute 'stages' in torchvision
            if hasattr(m, "stages") or m.__class__.__name__.lower().startswith("convnext"):
                return m
        # Fallback to first child if structure differs
        return list(enc.children())[0]
    else:
        raise NotImplementedError(
            f"Grad-CAM target auto-pick not implemented for backbone='{backbone_name}'. "
            "ViT/Swin require transformer-aware CAM."
        )

class GradCAM:
    """
    Generic Grad-CAM for conv backbones. No hard-coded shapes:
    - caches feature maps at target layer forward
    - caches gradients at target layer backward
    - produces a (H_in, W_in) heatmap via bilinear upsampling
    """
    def __init__(self, model: nn.Module, target_layer: nn.Module, out_size: Tuple[int, int]=(224, 224)):
        self.model = model.eval()
        self.target_layer = target_layer
        self.out_size = out_size

        self._fmap = None   # (N, C, H, W)
        self._grad = None   # (N, C, H, W)
        self._handles = []
        self._handles.append(self.target_layer.register_forward_hook(self._fhook))
        self._handles.append(self.target_layer.register_full_backward_hook(self._bhook))

    def _fhook(self, module, inputs, output):
        self._fmap = output

    def _bhook(self, module, grad_input, grad_output):
        self._grad = grad_output[0]

    def __call__(self, x: torch.Tensor, target_index: int) -> torch.Tensor:
        """
        x: (1,3,H,W) input tensor
        target_index: which logit/regression output to explain (int)
        returns: (H_in, W_in) heatmap in [0,1], torch.float32 CPU tensor
        """
        # Clear stale grads
        for p in self.model.parameters():
            if p.grad is not None:
                p.grad = None

        # Forward/backward
        y = self.model(x)              # (1, D)
        score = y[0, target_index]
        score.backward()

        if self._fmap is None or self._grad is None:
            raise RuntimeError("Hooks did not capture fmap/grad. Check target layer.")

        # Expect feature maps with spatial dims
        if self._fmap.dim() != 4:
            raise RuntimeError(f"Target layer output must be 4D (N,C,H,W); got {self._fmap.shape}")

        # Grad-CAM weights: GAP over spatial dims for each channel
        # shapes: fmap=(1,C,H,W), grad=(1,C,H,W) -> weights=(C,)
        weights = F.adaptive_avg_pool2d(self._grad, 1).squeeze(0).squeeze(-1).squeeze(-1)  # (C,)
        fmap = self._fmap.squeeze(0)  # (C,H,W)

        # Weighted sum over channels -> (H,W)
        cam = torch.sum(weights[:, None, None] * fmap, dim=0)
        cam = F.relu(cam)

        # Normalize → upsample → normalize again for numerical stability
        if cam.max() <= 0:
            heat = torch.zeros(self.out_size, dtype=torch.float32, device=cam.device)
        else:
            cam = (cam - cam.min()) / (cam.max() - cam.min() + 1e-8)
            heat = F.interpolate(
                cam[None, None], size=self.out_size, mode="bilinear", align_corners=False
            ).squeeze(0).squeeze(0)
            heat = (heat - heat.min()) / (heat.max() - heat.min() + 1e-8)

        return heat.detach().cpu().numpy()

    def close(self):
        for h in self._handles:
            h.remove()
        self._handles = []



# --------------------------
# Step 5: Load Trained Model (ConvNeXt-Tiny)
# --------------------------
# Initialize AQINet with the SAME backbone as training (convnext_tiny)
model = AQINet(
    backbone="resnet18",  # Critical: Must match training!
    output_dim=1,
    pretrained=True,
    head_hidden=256,
    dropout=0.2
).to(device)

# Load trained weights (safe, no UnpicklingError because we saved only state_dict)
state = torch.load("best_single_image_model_CO.pth", map_location=device, weights_only=True)
model.load_state_dict(state, strict=False)  # only if strict=True fail
# --------------------------
# Step 6: Select CORRECT Target Layer (ConvNeXt-Specific)
# --------------------------
# For ConvNeXt-Tiny: Target layer is the RAW feature extractor (before GAP in AQINet)
# Get the original ConvNeXt features (m.features) from AQINet's encoder
# AQINet's encoder for ConvNeXt is: [ConvNeXt.features, AdaptiveAvgPool2d, Flatten]
# Option A (robust): use the helper you already defined
target_layer = get_cam_target_layer(model, backbone_name="resnet18")
cam = GradCAM(model, target_layer, out_size=(224, 224))
# Option B (your original indexing, if you prefer):
# target_layer = model.encoder[0]
# cam = GradCAM(model, target_layer, out_size=(224, 224))


# --------------------------
# Step 7: Image Preprocessing (MATCH Training!)
# --------------------------
# Training used NO normalization—so CAM must use NO normalization!
# (Critical fix: Your training transform had no Normalize, but CAM did—caused mismatched inputs)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Same as training
    transforms.ToTensor()           # Same as training (scales to 0-1, no normalization)
])

# Load and preprocess the image
image_path = "all_images/image202506010100.jpg"  # Replace with your image path
img_original = Image.open(image_path).convert('RGB')
img_224 = transform(img_original).unsqueeze(0).to(device)  # Add batch dim: (1,3,224,224)

# Convert tensor back to PIL image for plotting (no need to invert normalization)
# ToTensor() scales to 0-1 → multiply by 255 to get 0-255 (standard for images)
img_224_plot = (img_224.squeeze().cpu().numpy() * 255).astype(np.uint8)
img_224_plot = np.transpose(img_224_plot, (1, 2, 0))  # (C,H,W) → (H,W,C) for plotting


# --------------------------
# Step 8: Generate Heatmaps & Visualize
# --------------------------
pollutant_names = ['CO']

# Generate 1 heatmap per pollutant (7 total)
heatmaps_224 = [cam(img_224, dim) for dim in range(len(pollutant_names))]

# Plot results (all 224x224, aligned with model input)
plt.figure(figsize=(16, 12))

# Show model input (224x224, exactly what the model sees)
plt.subplot(3, 3, 1)
plt.imshow(img_224_plot)
plt.title("Model Input (224x224)", fontsize=12, fontweight='bold')
plt.axis('off')

# Show heatmap for each pollutant
for i in range(len(pollutant_names)):
    plt.subplot(3, 3, i + 2)
    plt.imshow(img_224_plot)  # Base image (no color distortion)
    # Overlay heatmap (red = regions that increase pollutant prediction)
    plt.imshow(heatmaps_224[i], cmap='jet', alpha=0.5)
    plt.title(f"{pollutant_names[i]}", fontsize=12)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

pollutants = ['CO']
n_vars = len(pollutants)

plt.figure(figsize=(18, 10))
for i in range(n_vars):
    plt.subplot(2, 4, i+1)
    # Use regplot for scatter and regression line
    sns.regplot(x=y_train_true[:, i], y=y_train_pred[:, i], scatter_kws={'alpha': 0.5, 's': 20}, line_kws={'color': 'red', 'linestyle': '--'})
    plt.xlabel("True")
    plt.ylabel("Predicted")
    plt.title(pollutants[i])
plt.tight_layout()
plt.suptitle("Predicted vs. True AQI Values", fontsize=16, y=1.05)
plt.show()

plt.figure(figsize=(18, 10))
for i in range(n_vars):
    plt.subplot(2, 4, i+1)
    plt.scatter(y_train_true[:, i], y_train_pred[:, i], alpha=0.5, s=20)
    plt.plot([y_train_true[:, i].min(), y_train_true[:, i].max()],
    [y_train_true[:, i].min(), y_train_true[:, i].max()], 'r--')
    plt.xlabel("True")
    plt.ylabel("Predicted")
    plt.title(pollutants[i])
plt.tight_layout()
plt.suptitle("Predicted vs. True AQI Values", fontsize=16, y=1.05)
plt.show()

from sklearn.metrics import r2_score
r2_scores = [r2_score(y_train_true[:, i], y_train_pred[:, i]) for i in range(n_vars)]
plt.figure(figsize=(4, 3))
plt.bar(pollutants, r2_scores)
plt.ylabel("R² Score")
plt.title("R² Scores for Each AQI Variable")
plt.ylim(-1, 1)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Step 7: Save your trained model

# %%
# torch.save(model.state_dict(), 'best_single_image_model.pth')
# print('Model saved successfully.')

# %% [markdown]
# ## Step 8: Prediction function & Demo

# %%
import os
from pathlib import Path
import pandas as pd
from PIL import Image
import torch
from torchvision import transforms

# -------- settings --------
input_path = Path("YauTsingMong/")   # single image OR folder
output_csv = "YauTsingMong_CO.csv"
valid_exts = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".webp"}

# ensure model ready
model.to(device)
# Load trained weights (safe, no UnpicklingError because we saved only state_dict)
state = torch.load("best_single_image_model_CO.pth", map_location=device, weights_only=True)
model.load_state_dict(state, strict=False)  # only if strict=True fails
model.eval()

# same transform as training
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

def predict_aqi(image_path, model, device):
    img = Image.open(image_path).convert('RGB')
    img_tensor = transform(img).unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(img_tensor).cpu().numpy()[0]

    return {
        "CO": output[0],

    }

def _list_images(folder: Path):
    return sorted(
        [p for p in folder.iterdir() if p.is_file() and p.suffix.lower() in valid_exts],
        key=lambda p: p.name
    )

# -------- run --------
if input_path.is_file():
    pred = predict_aqi(str(input_path), model, device)
    print(f"\nPredicted AQI values for {input_path.name}:")
    for k, v in pred.items():
        print(f"  {k}: {v:.3f}")

elif input_path.is_dir():
    images = _list_images(input_path)
    if not images:
        raise ValueError(f"No valid images found in {input_path}")

    rows = []
    for img_path in tqdm(images, desc="Inferring"):
        pred = predict_aqi(str(img_path), model, device)
        print(f"\n{img_path.name}:")
        for k, v in pred.items():
            print(f"  {k}: {v:.3f}")
        row = {"Filename": img_path.name}
        row.update(pred)
        rows.append(row)

    df = pd.DataFrame(rows, columns=["Filename", "CO"])
    df.to_csv(output_csv, index=False, encoding="utf-8-sig")
    print(f"\nSaved predictions to: {output_csv}")


else:
    raise FileNotFoundError(f"Path not found: {input_path}")
# Out:
# Inferring:   0%|          | 0/15313 [00:00<?, ?it/s]
# 0_114.155583_22.32122_1708.jpg:
#   CO: 1.689
#
# 10000_114.162297_22.322854_1707.jpg:
#   CO: 1.579
#
# 10001_114.162389_22.322789_1707.jpg:
#   CO: 1.674
#
# 10002_114.16245_22.322744_1707.jpg:
#   CO: 1.600
#
# 10003_114.162547_22.322672_1707.jpg:
#   CO: 1.643
#
# 10004_114.162618_22.322616_1707.jpg:
#   CO: 1.643
#
# 10005_114.170731_22.303207_1403.jpg:
#   CO: 1.802
#
# 10006_114.174095_22.307108_1707.jpg:
#   CO: 1.503
#
# 10007_114.169774_22.312886_1707.jpg:
#   CO: 1.644
#
# 10008_114.169875_22.312902_1707.jpg:
#   CO: 1.743
#
# 10009_114.16998_22.312917_1707.jpg:
#   CO: 1.786
#
# 1000_114.166354_22.303694_1403.jpg:
#   CO: 1.756
#
# 10010_114.18292_22.30343_1708.jpg:
#   CO: 1.575
#
# 10011_114.182943_22.303325_1708.jpg:
#   CO: 1.562
#
# 10012_114.182965_22.303224_1708.jpg:
#   CO: 1.580
#
# 10013_114.182988_22.30308_1708.jpg:
#   CO: 1.658
#
# 10014_114.182996_22.302923_1708.jpg:
#   CO: 1.516
#
# 10015_114.179586_22.301709_1708.jpg:
#   CO: 1.590
#
# 10016_114.169813_22.308757_1707.jpg:
#   CO: 1.760
#
# 10017_114.169713_22.30878_1707.jpg:
#   CO: 1.697
#
# 10018_114.170658_22.303111_1707.jpg:
#   CO: 1.773
#
# 10019_114.170585_22.303107_1707.jpg:
#   CO: 1.803
#
# 1001_114.166358_22.30375_1403.jpg:
#   CO: 1.776
#
# 10020_114.170529_22.303084_1707.jpg:
#   CO: 1.865
#
# 10021_114.165967_22.322059_1708.jpg:
#   CO: 1.581
#
# 10022_114.165982_22.322005_1708.jpg:
#   CO: 1.580
#
# 10023_114.165998_22.321908_1708.jpg:
#   CO: 1.600
#
# 10024_114.166021_22.321838_1708.jpg:
#   CO: 1.546
#
# 10025_114.166034_22.321767_1708.jpg:
#   CO: 1.589
#
# 10026_114.166051_22.321683_1708.jpg:
#   CO: 1.584
#
# 10027_114.166059_22.321612_1708.jpg:
#   CO: 1.747
#
